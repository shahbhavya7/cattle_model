# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    AnimalNo  WHHeightAtWither  Rumpheight  BLBodylengthcm  \
# 0       436               132         139             190
# 1        26               131         140             183
# 2         2               143         147             197
# 3     11112               139         146             202
# 4         8               144         160             185
#
#    Scapuloischiallength  SternumHeight  ChestDepth  RumpWidth  RumpLength  \
# 0                   150             58          83         43          40
# 1                   150             58          85         42          38
# 2                   154             67          95         41          30
# 3                   174             78          82         45          36
# 4                   152             67          84         43          36
#
#    HeartGirth  AbdGirth  CannonBoneDiameter  HockBoneDiameter  \
# 0         172       217                18.0                40
# 1         172       215                18.0                40
# 2         188       217                18.0                51
# 3         185       203                17.0                56
# 4         179       216                19.0                46
#
#    ActualBodyWeight
# 0               379
# 1               398
# 2               407
# 3               412
# 4               413

# %%
df.shape
# Out:
# (517, 14)

# %%
df.describe()
# Out:
#             AnimalNo  WHHeightAtWither  Rumpheight  BLBodylengthcm  \
# count     517.000000        517.000000  517.000000      517.000000
# mean    10800.692456        151.431335  160.756286      212.661509
# std     66719.581279          6.173024    6.408765       11.880034
# min         2.000000        131.000000  139.000000      177.000000
# 25%      2740.000000        147.000000  157.000000      206.000000
# 50%      3425.000000        152.000000  161.000000      213.000000
# 75%      4186.000000        156.000000  165.000000      220.000000
# max    999113.000000        169.000000  180.000000      246.000000
#
#        Scapuloischiallength  SternumHeight  ChestDepth   RumpWidth  \
# count            517.000000     517.000000  517.000000  517.000000
# mean             177.071567      65.847195   99.266925   46.340426
# std                9.689196       4.981930    5.277046    4.553320
# min              145.000000      54.000000   82.000000   35.000000
# 25%              171.000000      62.000000   96.000000   43.000000
# 50%              178.000000      66.000000  100.000000   46.000000
# 75%              184.000000      69.000000  103.000000   50.000000
# max              204.000000      80.000000  116.000000   59.000000
#
#        RumpLength  HeartGirth    AbdGirth  CannonBoneDiameter  \
# count  517.000000  517.000000  517.000000          517.000000
# mean    37.845261  202.653772  245.994197           20.277563
# std      3.568168    9.794697   13.357124            1.211556
# min     28.000000  171.000000  203.000000           17.000000
# 25%     36.000000  196.000000  238.000000           20.000000
# 50%     38.000000  203.000000  246.000000           20.000000
# 75%     40.000000  210.000000  255.000000           21.000000
# max     49.000000  233.000000  282.000000           24.000000
#
#        HockBoneDiameter  ActualBodyWeight
# count        517.000000        517.000000
# mean          48.837524        602.344294
# std            4.830530         78.114614
# min           40.000000        379.000000
# 25%           45.000000        547.000000
# 50%           48.000000        601.000000
# 75%           52.000000        653.000000
# max           64.000000        824.000000

# %%
# check for missing values
df.isnull().sum()
# Out:
# AnimalNo                0
# WHHeightAtWither        0
# Rumpheight              0
# BLBodylengthcm          0
# Scapuloischiallength    0
# SternumHeight           0
# ChestDepth              0
# RumpWidth               0
# RumpLength              0
# HeartGirth              0
# AbdGirth                0
# CannonBoneDiameter      0
# HockBoneDiameter        0
# ActualBodyWeight        0
# dtype: int64

# %%
# checking duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check data types
df.dtypes
# Out:
# AnimalNo                  int64
# WHHeightAtWither          int64
# Rumpheight                int64
# BLBodylengthcm            int64
# Scapuloischiallength      int64
# SternumHeight             int64
# ChestDepth                int64
# RumpWidth                 int64
# RumpLength                int64
# HeartGirth                int64
# AbdGirth                  int64
# CannonBoneDiameter      float64
# HockBoneDiameter          int64
# ActualBodyWeight          int64
# dtype: object

# %%
# change data types if necessary
# df['column_name'] = df['column_name'].astype('desired_type')
df['CannonBoneDiameter'] = df['CannonBoneDiameter'].astype(int)

# %%
df.head()
# Out:
#    AnimalNo  WHHeightAtWither  Rumpheight  BLBodylengthcm  \
# 0       436               132         139             190
# 1        26               131         140             183
# 2         2               143         147             197
# 3     11112               139         146             202
# 4         8               144         160             185
#
#    Scapuloischiallength  SternumHeight  ChestDepth  RumpWidth  RumpLength  \
# 0                   150             58          83         43          40
# 1                   150             58          85         42          38
# 2                   154             67          95         41          30
# 3                   174             78          82         45          36
# 4                   152             67          84         43          36
#
#    HeartGirth  AbdGirth  CannonBoneDiameter  HockBoneDiameter  \
# 0         172       217                  18                40
# 1         172       215                  18                40
# 2         188       217                  18                51
# 3         185       203                  17                56
# 4         179       216                  19                46
#
#    ActualBodyWeight
# 0               379
# 1               398
# 2               407
# 3               412
# 4               413
